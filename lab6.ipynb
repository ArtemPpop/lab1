# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

firms = pd.DataFrame({
    'Название фирмы': [
        'Телефон-Сервис', 'СвязьПлюс', 'МобайлТех',
        'ГигаКом', 'Фонлайн', 'СмартСвязь', 'ТелеСеть'
    ],
    'Дата регистрации договора': pd.to_datetime([
        '2015-03-10', '2018-07-23', '2020-02-15',
        '2012-11-01', '2016-05-17', '2019-12-05', '2014-01-20'
    ]),
    'Адрес': [
        'Москва, ул. Ленина, 10',
        'Санкт-Петербург, Невский пр., 45',
        'Казань, ул. Баумана, 7',
        'Екатеринбург, ул. Мира, 22',
        'Новосибирск, ул. Советская, 15',
        'Ростов-на-Дону, ул. Пушкина, 5',
        'Воронеж, ул. Кирова, 33'
    ],
    'Номер телефона': [
        '+7 (495) 111-22-33',
        '+7 (812) 222-33-44',
        '+7 (843) 333-44-55',
        '+7 (343) 444-55-66',
        '+7 (383) 555-66-77',
        '+7 (863) 666-77-88',
        '+7 (473) 777-88-99'
    ],
    'Директор': [
        'Иванов И.И.',
        'Петров П.П.',
        'Сидоров С.С.',
        'Кузнецов К.К.',
        'Орлова А.А.',
        'Громов Г.Г.',
        'Федорова Л.Л.'
    ]
})
firms
# Out:
#    Название фирмы Дата регистрации договора                             Адрес  \
# 0  Телефон-Сервис                2015-03-10            Москва, ул. Ленина, 10
# 1       СвязьПлюс                2018-07-23  Санкт-Петербург, Невский пр., 45
# 2       МобайлТех                2020-02-15            Казань, ул. Баумана, 7
# 3         ГигаКом                2012-11-01        Екатеринбург, ул. Мира, 22
# 4         Фонлайн                2016-05-17    Новосибирск, ул. Советская, 15
# 5      СмартСвязь                2019-12-05    Ростов-на-Дону, ул. Пушкина, 5
# 6        ТелеСеть                2014-01-20           Воронеж, ул. Кирова, 33
#
#        Номер телефона       Директор
# 0  +7 (495) 111-22-33    Иванов И.И.
# 1  +7 (812) 222-33-44    Петров П.П.
# 2  +7 (843) 333-44-55   Сидоров С.С.
# 3  +7 (343) 444-55-66  Кузнецов К.К.
# 4  +7 (383) 555-66-77    Орлова А.А.
# 5  +7 (863) 666-77-88    Громов Г.Г.
# 6  +7 (473) 777-88-99  Федорова Л.Л.

# %%
today = datetime.now()
firms['Лет сотрудничества'] = today.year - firms['Дата регистрации договора'].dt.year
